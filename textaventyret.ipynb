# %% [markdown]
# <a href="https://colab.research.google.com/github/gandhionthehub/CSI/blob/main/textaventyret.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# -- my text adventure --
from IPython.display import clear_output
inventory = []
import os
from time import sleep



def nocrash():
  if ValueError == 1





print(f"Before we begin, what's your name?...")
username = input()
print(f"Welcome to the DARK ROOM Sir, {username}!")


sysmsg = "Loading"
for i in range(4):
  sysmsg += "."
  print(sysmsg)
  sleep(1)
print(f"Done........")
clear_output()

print(f"Amidst the darkness, you can somewhat make out the silhouette of a griffin statue.\nSince there isn't anything else amongst the dark void that you find yourself in, you decide to approach it.")
print(f"???: Greetings traveler.")

msg = "."
for x in range(4):
  msg + "."


print(f"???: Care for a puzzle?")
print(f"{username}: yes/no")
puzzle = input().lower()

result = 0

if puzzle == "yes":
  clear_output()
  print(f"???: Now listen carefully, you only get ONE chance.")
  print(f"???: What is big and fluffy, yet green and prickly?")
  result = input().lower()
clear_output()


if result == "cactus":
  print(f"???: CONGRATULATIONS! You have answered my riddle correctly. Please take my sword.")
  print(f"\033[93m-sword acquired-\033[0m")
  inventory.append("sword")
else:
  print(f"???: GET OUT OF MY SIGHT PEASANT")
  print(f"\033[91m --- you died... ---\033[0m")
  clear_output()

print(f"With the sword in hand you notice a faint glow pointing towards the dark.")
print(f"Do you wish to follow? (yes/no)")
trail_end = input().lower()

clear_output()

if trail_end == "yes":
  print(f"You choose to follow the faint light into the darkness.")
  print(f"As you walk it feels as thus your breath is getting heavier. And heavier.")
  print(f"You tighten your grip on the sword in an attempt to feel its comfort.")

else:
  print(f"As you stand there with nothing but the company of your own breath.")
  print(f"You feel alone. Solitary.")
  print(f"The sword speaks to you.")
  print(f"You feel the sharp blade as the darkness around you turns white.")
  print(f"\033[91m --- you died... ---\033[0m")
# Out:
# Amidst the darkness, you can somewhat make out the silhouette of a griffin statue.
# Since there isn't anything else amongst the dark void that you find yourself in, you decide to approach it.
# ???: Greetings traveler.
# ???: Care for a puzzle?
# yr: yes/no
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_855/1575648973.py in <cell line: 0>()
#      29 print(f"???: Care for a puzzle?")
#      30 print(f"{username}: yes/no")
# ---> 31 puzzle = input().lower()
#      32
#      33 result = 0
#
# /usr/local/lib/python3.13/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# ...
